# %% [markdown]
# ## This notebook includes:
#
# ### Training a regularized Softmax classifier on MNIST dataset
#
# ### Computing mini-batch stochastic gradients in MB-SGD, and train the linear model with multiple settings and parameters

# %% [markdown]
# ## 1. Load/Download MNIST dataset using pytorch

# %%
import matplotlib.pyplot as plt
import numpy
from torchvision import datasets, transforms

train_set = datasets.MNIST('./data', train=True, download=True)
test_set = datasets.MNIST('./data', train=False, download=True)

x_train = train_set.data.numpy()
x_train = x_train.reshape(len(x_train),-1)
x_test = test_set.data.numpy()
x_test = x_test.reshape(len(x_test),-1)

y_train = train_set.targets.numpy()
y_test = test_set.targets.numpy()

print('Shape of x_train: ' + str(x_train.shape))
print('Shape of x_test: ' + str(x_test.shape))

print('Shape of y_train: ' + str(y_train.shape))
print('Shape of y_test: ' + str(y_test.shape))
# Out:
# Shape of x_train: (60000, 784)
# Shape of x_test: (10000, 784)
# Shape of y_train: (60000,)
# Shape of y_test: (10000,)

# %% [markdown]
# ## 2. Scale features

# %%
# calculate mu and sig using the training set
d = x_train.shape[1]
mu = numpy.mean(x_train, axis=0).reshape(1, d)
sig = numpy.std(x_train, axis=0).reshape(1, d)

# transform the training features
x_train = (x_train - mu) / (sig + 1E-6)

# transform the test features
x_test = (x_test - mu) / (sig + 1E-6)

# %% [markdown]
# ## 3. Visualize a random image

# %%
d = x_train.shape[0]
random_index = numpy.random.randint(d, size=1)[0]
plt.imshow(x_train[random_index].reshape(28,28), cmap = "gray")
print('Its label is')
print(y_train[random_index])
# Out:
# Its label is
# 6

# %% [markdown]
# ## 4. Define softmax function and cross entropy loss

# %%
def softmax(z):
    """implement the softmax functions
    input: numpy ndarray
    output: numpy ndarray
    """
    exp_list = numpy.exp(z)
    result = 1/sum(exp_list) * exp_list
    result = result.reshape((len(z),1))
    assert (result.shape == (len(z),1))
    return result

def neg_log_loss(pred, label):
    """implement the negative log loss"""
    loss = -numpy.log(pred[int(label)])
    return loss

# %% [markdown]
# ## 5. Functions for implementing linear softmax classifier

# %%
import os
import sys
import json

root = os.path.abspath('./')
root += '/configs/'

def loadConfig(name):
    """ Read a configuration file as a dictionary"""
    full_path = root + name
    json_file = open(full_path, 'r')
    cfg = json.load(json_file)
    json_file.close()
    return cfg

def initialize(num_inputs,num_classes):
    """initialize the parameters"""
    # num_inputs = 28*28 = 784
    # num_classes = 10
    w = numpy.zeros((num_classes, num_inputs)) # (10*784)
    
    param = {
        'w' : w, # (10*784)t
    }
    return param

def eval(param, hyp, x_data, y_data):
    """ implement the evaluation function
    input: param -- parameters dictionary (w)
           hyp -- hyper-parameter: we use hyp['lambda'] to compute regularization
           x_data -- x_train or x_test (size, 784)
           y_data -- y_train or y_test (size,)
    output: loss and accuracy
    """
    
    reg_lambda = hyp['lambda']
    
    # w: (10*784), x: (10000*784), y:(10000,)
    loss_list = []
    w = param['w'].transpose()
    dist = numpy.array([numpy.squeeze(softmax(numpy.matmul(x_data[i], w))) for i in range(len(y_data))])

    result = numpy.argmax(dist,axis=1)
    accuracy = sum(result == y_data)/float(len(y_data))

    loss_list = [neg_log_loss(dist[i],y_data[i]) for i in range(len(y_data))]
    loss = sum(loss_list) / len(loss_list) + reg_lambda/2 * numpy.sum(w * w)
    return loss, accuracy

def train(param, hyp, x_train, y_train, x_test, y_test,cfg_idx):
    """ implement the train function
    input: param -- parameters dictionary (w)
           hyp -- hyperparameters dictionary
           x_train -- (60000, 784)
           y_train -- (60000,)
           x_test -- x_test (10000, 784)
           y_test -- y_test (10000,)
    output: train_loss_list, train_acc_list, test_loss_list, test_acc_list
           Four lists contain the epoch-wise loss function on training data, accuracy on training data, loss function on testing data, accuracy on testing data, respectively
    """
    num_epoches = hyp['num_epoches']
    batch_size = hyp['batch_size']
    learning_rate = hyp['learning_rate']
    mu = hyp['mu']
    reg_lambda = hyp['lambda']
    train_loss_list, train_acc_list, test_loss_list, test_acc_list = [],[],[],[]
    if bool(hyp['momentum']) == True:
        w_velocity = numpy.zeros(param['w'].shape)
        b_velocity = numpy.zeros(param['b'].shape) 

    for epoch in range(num_epoches):
        
        # select the random sequence of training set
        rand_indices = numpy.random.choice(x_train.shape[0],x_train.shape[0],replace=False)
        num_batch = int(x_train.shape[0]/batch_size)
        
        if bool(hyp['learning_decay']) == True:
            try:
                if test_acc_list[-1] - test_acc_list[-2] < 0.001:
                    learning_rate *= hyp['decay_factor']
            except:
                pass
            
            message = 'learning rate: %.8f' % learning_rate
            print(message)
            logging.info(message)

        # for each batch of train data
        for batch in range(num_batch):
            index = rand_indices[batch_size*batch:batch_size*(batch+1)]
            x_batch = x_train[index]
            y_batch = y_train[index]

            # calculate the stochastic gradient w.r.t w 
            dw, batch_loss = mini_batch_gradient(param, x_batch, y_batch, reg_lambda)

            param['w'] -= learning_rate * dw
            
            if (batch+1) % 100 == 0:
                message = 'Epoch [%d/%d], Batch [%d/%d], Loss %.4f' % (epoch+1, num_epoches, batch+1, num_batch, batch_loss)
                print(message)

        train_loss, train_acc = eval(param,hyp,x_train,y_train)
        test_loss, test_acc = eval(param,hyp,x_test,y_test)
        train_loss_list.append(train_loss)
        train_acc_list.append(train_acc)
        test_loss_list.append(test_loss)
        test_acc_list.append(test_acc)

        message = 'Epoch %d/%d, Train Loss %.4f, Train Acc %.4f, Test Loss %.4f, Test Acc %.4f' % (epoch+1, num_epoches, train_loss, train_acc, test_loss, test_acc)
        print(message)
        logging.info(message)
    return train_loss_list, train_acc_list, test_loss_list, test_acc_list


def plot(train_loss_list, train_acc_list, test_loss_list, test_acc_list, cfg_idx):
    """store the plots"""
    # epoch_list = list(range(len(loss_list)))
    plt.plot(train_loss_list, '-b', label='train loss')
    plt.plot(test_loss_list, '-r', label='test loss')
    plt.legend()
    plt.ylabel('Loss Function')
    plt.xlabel('Epoch')
    plt.xticks(rotation=60)
    plt.title('Loss Function ~ Epoch')
    plt.savefig('assets/loss_{}.png'.format(cfg_idx))
    plt.show()
    
    plt.plot(train_acc_list, '-b', label='train acc')
    plt.plot(test_acc_list, '-r', label='test acc')
    plt.legend()
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.xticks(rotation=60)
    plt.title('Accuracy ~ Epoch')
    plt.savefig('assets/accr_{}.png'.format(cfg_idx))
    plt.show()
    

def main(cfg_idx): 
#     cfg_idx = args.config
    cfg_name = 'config_{}.json'.format(cfg_idx)
    hyperpara = loadConfig(cfg_name)

    # setting the random seed
    numpy.random.seed(1024)

    # initialize the parameters
    num_inputs = x_train.shape[1]
    num_classes = len(set(y_train))
    param = initialize(num_inputs,num_classes)

    # train the model
    train_loss_list, train_acc_list, test_loss_list, test_acc_list = train(param,hyperpara,x_train,y_train,x_test,y_test, cfg_idx)

    # plot the loss and accuracy
    plot(train_loss_list, train_acc_list, test_loss_list, test_acc_list, cfg_idx)

# %% [markdown]
# ## 6. Implementation of mini-batch gradients

# %%
def mini_batch_gradient(param, x_batch, y_batch, reg_lambda):
    """implement the function to compute the mini batch gradient
    input: param -- parameters dictionary (w)
           x_batch -- a batch of x (size, 784)
           y_batch -- a batch of y (size,)
           reg_lambdba -- regularization parameter
    output: 
           dw -- derivative w.r.t. weight w
           batch_loss -- average loss on the mini-batch samples
    """
    
    # Your code goes here
    batch_size = len(y_batch)
    w = param['w']
    dw = numpy.zeros(w.shape)
    loss = 0
    for b in range(batch_size):
      y_vector = numpy.zeros((10,1))

      # convert the labels to one-hot encode data
      y_vector[y_batch[b]] = 1
      
      dw += numpy.matmul(numpy.array(softmax(numpy.matmul(w, x_batch[b,:])) - y_vector), numpy.expand_dims(x_batch[b,:], axis = 0))
      
      loss += -numpy.sum(numpy.log(softmax(numpy.matmul(w, x_batch[b,:]))) * y_vector)


    batch_loss = loss/batch_size
    dw = numpy.array(dw/batch_size + reg_lambda*w)
    
    return dw, batch_loss

# %% [markdown]
# ## 7. Train model using the configuration "setting 1"

# %%
if os.path.isdir('logs') == False:
    os.mkdir('logs')
    
if os.path.isdir('assets') == False:
    os.mkdir('assets')
    
    
if __name__ == "__main__":

    cfg_idx = 'setting_1'

# configuration in setting 1:
#     {
#     "num_epoches" : 50,
#     "batch_size" : 6000,
#     "learning_rate" : 0.1,
#     "learning_decay" : 0,
#     "decay_factor" : 0.75,
#     "momentum" : 0,
#     "lambda" : 0.00,
#     "mu" : 0.9
# }
    
    import logging
    logging.basicConfig(filename="./logs/{}.log".format(cfg_idx), filemode="w", format="%(message)s", level=logging.DEBUG)
    
    main(cfg_idx)
# Out:
# Epoch 1/50, Train Loss 0.6474, Train Acc 0.8485, Test Loss 0.6310, Test Acc 0.8568
# Epoch 2/50, Train Loss 0.5096, Train Acc 0.8733, Test Loss 0.4951, Test Acc 0.8789
# Epoch 3/50, Train Loss 0.4527, Train Acc 0.8830, Test Loss 0.4399, Test Acc 0.8868
# Epoch 4/50, Train Loss 0.4203, Train Acc 0.8897, Test Loss 0.4088, Test Acc 0.8923
# Epoch 5/50, Train Loss 0.3988, Train Acc 0.8931, Test Loss 0.3886, Test Acc 0.8971
# Epoch 6/50, Train Loss 0.3833, Train Acc 0.8964, Test Loss 0.3741, Test Acc 0.8994
# Epoch 7/50, Train Loss 0.3713, Train Acc 0.8989, Test Loss 0.3632, Test Acc 0.9014
# Epoch 8/50, Train Loss 0.3618, Train Acc 0.9008, Test Loss 0.3544, Test Acc 0.9036
# Epoch 9/50, Train Loss 0.3541, Train Acc 0.9024, Test Loss 0.3475, Test Acc 0.9046
# Epoch 10/50, Train Loss 0.3475, Train Acc 0.9035, Test Loss 0.3415, Test Acc 0.9055
# Epoch 11/50, Train Loss 0.3419, Train Acc 0.9050, Test Loss 0.3367, Test Acc 0.9066
# Epoch 12/50, Train Loss 0.3370, Train Acc 0.9062, Test Loss 0.3324, Test Acc 0.9074
# Epoch 13/50, Train Loss 0.3327, Train Acc 0.9069, Test Loss 0.3287, Test Acc 0.9083
# Epoch 14/50, Train Loss 0.3289, Train Acc 0.9080, Test Loss 0.3254, Test Acc 0.9090
# Epoch 15/50, Train Loss 0.3256, Train Acc 0.9090, Test Loss 0.3227, Test Acc 0.9099
# Epoch 16/50, Train Loss 0.3225, Train Acc 0.9097, Test Loss 0.3201, Test Acc 0.9105
# Epoch 17/50, Train Loss 0.3197, Train Acc 0.9104, Test Loss 0.3178, Test Acc 0.9114
# Epoch 18/50, Train Loss 0.3171, Train Acc 0.9112, Test Loss 0.3157, Test Acc 0.9120
# Epoch 19/50, Train Loss 0.3148, Train Acc 0.9118, Test Loss 0.3139, Test Acc 0.9122
# Epoch 20/50, Train Loss 0.3126, Train Acc 0.9123, Test Loss 0.3122, Test Acc 0.9129
# Epoch 21/50, Train Loss 0.3106, Train Acc 0.9129, Test Loss 0.3106, Test Acc 0.9131
# Epoch 22/50, Train Loss 0.3088, Train Acc 0.9134, Test Loss 0.3091, Test Acc 0.9134
# Epoch 23/50, Train Loss 0.3070, Train Acc 0.9139, Test Loss 0.3078, Test Acc 0.9139
# Epoch 24/50, Train Loss 0.3054, Train Acc 0.9143, Test Loss 0.3066, Test Acc 0.9142
# Epoch 25/50, Train Loss 0.3039, Train Acc 0.9147, Test Loss 0.3055, Test Acc 0.9145
# Epoch 26/50, Train Loss 0.3025, Train Acc 0.9151, Test Loss 0.3044, Test Acc 0.9146
# Epoch 27/50, Train Loss 0.3011, Train Acc 0.9155, Test Loss 0.3034, Test Acc 0.9150
# Epoch 28/50, Train Loss 0.2998, Train Acc 0.9160, Test Loss 0.3025, Test Acc 0.9151
# Epoch 29/50, Train Loss 0.2986, Train Acc 0.9164, Test Loss 0.3017, Test Acc 0.9151
# Epoch 30/50, Train Loss 0.2975, Train Acc 0.9165, Test Loss 0.3009, Test Acc 0.9153
# Epoch 31/50, Train Loss 0.2964, Train Acc 0.9169, Test Loss 0.3001, Test Acc 0.9158
# Epoch 32/50, Train Loss 0.2953, Train Acc 0.9172, Test Loss 0.2994, Test Acc 0.9158
# Epoch 33/50, Train Loss 0.2943, Train Acc 0.9175, Test Loss 0.2988, Test Acc 0.9158
# Epoch 34/50, Train Loss 0.2934, Train Acc 0.9177, Test Loss 0.2981, Test Acc 0.9162
# Epoch 35/50, Train Loss 0.2925, Train Acc 0.9182, Test Loss 0.2975, Test Acc 0.9159
# Epoch 36/50, Train Loss 0.2916, Train Acc 0.9185, Test Loss 0.2969, Test Acc 0.9162
# Epoch 37/50, Train Loss 0.2908, Train Acc 0.9186, Test Loss 0.2963, Test Acc 0.9162
# Epoch 38/50, Train Loss 0.2900, Train Acc 0.9190, Test Loss 0.2959, Test Acc 0.9165
# Epoch 39/50, Train Loss 0.2892, Train Acc 0.9192, Test Loss 0.2954, Test Acc 0.9168
# Epoch 40/50, Train Loss 0.2885, Train Acc 0.9194, Test Loss 0.2949, Test Acc 0.9171
# Epoch 41/50, Train Loss 0.2877, Train Acc 0.9196, Test Loss 0.2945, Test Acc 0.9172
# Epoch 42/50, Train Loss 0.2871, Train Acc 0.9199, Test Loss 0.2941, Test Acc 0.9175
# Epoch 43/50, Train Loss 0.2864, Train Acc 0.9201, Test Loss 0.2937, Test Acc 0.9177
# Epoch 44/50, Train Loss 0.2857, Train Acc 0.9203, Test Loss 0.2933, Test Acc 0.9179
# Epoch 45/50, Train Loss 0.2851, Train Acc 0.9205, Test Loss 0.2930, Test Acc 0.9184
# Epoch 46/50, Train Loss 0.2845, Train Acc 0.9206, Test Loss 0.2926, Test Acc 0.9186
# Epoch 47/50, Train Loss 0.2839, Train Acc 0.9208, Test Loss 0.2923, Test Acc 0.9186
# Epoch 48/50, Train Loss 0.2834, Train Acc 0.9210, Test Loss 0.2920, Test Acc 0.9186
# Epoch 49/50, Train Loss 0.2828, Train Acc 0.9211, Test Loss 0.2917, Test Acc 0.9188
# Epoch 50/50, Train Loss 0.2823, Train Acc 0.9213, Test Loss 0.2914, Test Acc 0.9188

# %% [markdown]
# ## 7. Train model using the configuration "setting 2"

# %%
if __name__ == "__main__":

    cfg_idx = 'setting_2'

# configuration in setting 2:
#     {
#     "num_epoches" : 50,
#     "batch_size" : 600,
#     "learning_rate" : 0.1,
#     "learning_decay" : 0,
#     "decay_factor" : 0.75,
#     "momentum" : 0,
#     "lambda" : 0.00,
#     "mu" : 0.9
# }
    
    import logging
    logging.basicConfig(filename="./logs/{}.log".format(cfg_idx), filemode="w", format="%(message)s", level=logging.DEBUG)
    
    main(cfg_idx)
# Out:
# Epoch [1/50], Batch [100/100], Loss 0.3135
# Epoch 1/50, Train Loss 0.3483, Train Acc 0.9040, Test Loss 0.3427, Test Acc 0.9050
# Epoch [2/50], Batch [100/100], Loss 0.3320
# Epoch 2/50, Train Loss 0.3134, Train Acc 0.9120, Test Loss 0.3135, Test Acc 0.9123
# Epoch [3/50], Batch [100/100], Loss 0.3006
# Epoch 3/50, Train Loss 0.2981, Train Acc 0.9168, Test Loss 0.3012, Test Acc 0.9158
# Epoch [4/50], Batch [100/100], Loss 0.2690
# Epoch 4/50, Train Loss 0.2891, Train Acc 0.9192, Test Loss 0.2961, Test Acc 0.9165
# Epoch [5/50], Batch [100/100], Loss 0.2376
# Epoch 5/50, Train Loss 0.2832, Train Acc 0.9207, Test Loss 0.2931, Test Acc 0.9182
# Epoch [6/50], Batch [100/100], Loss 0.2895
# Epoch 6/50, Train Loss 0.2784, Train Acc 0.9218, Test Loss 0.2903, Test Acc 0.9200
# Epoch [7/50], Batch [100/100], Loss 0.2112
# Epoch 7/50, Train Loss 0.2747, Train Acc 0.9227, Test Loss 0.2887, Test Acc 0.9207
# Epoch [8/50], Batch [100/100], Loss 0.2331
# Epoch 8/50, Train Loss 0.2720, Train Acc 0.9244, Test Loss 0.2869, Test Acc 0.9222
# Epoch [9/50], Batch [100/100], Loss 0.2465
# Epoch 9/50, Train Loss 0.2693, Train Acc 0.9253, Test Loss 0.2870, Test Acc 0.9219
# Epoch [10/50], Batch [100/100], Loss 0.2607
# Epoch 10/50, Train Loss 0.2672, Train Acc 0.9261, Test Loss 0.2854, Test Acc 0.9233
# Epoch [11/50], Batch [100/100], Loss 0.2673
# Epoch 11/50, Train Loss 0.2654, Train Acc 0.9263, Test Loss 0.2862, Test Acc 0.9223
# Epoch [12/50], Batch [100/100], Loss 0.2896
# Epoch 12/50, Train Loss 0.2637, Train Acc 0.9268, Test Loss 0.2849, Test Acc 0.9231
# Epoch [13/50], Batch [100/100], Loss 0.3255
# Epoch 13/50, Train Loss 0.2622, Train Acc 0.9281, Test Loss 0.2850, Test Acc 0.9225
# Epoch [14/50], Batch [100/100], Loss 0.2403
# Epoch 14/50, Train Loss 0.2610, Train Acc 0.9284, Test Loss 0.2841, Test Acc 0.9240
# Epoch [15/50], Batch [100/100], Loss 0.2638
# Epoch 15/50, Train Loss 0.2601, Train Acc 0.9283, Test Loss 0.2855, Test Acc 0.9231
# Epoch [16/50], Batch [100/100], Loss 0.2734
# Epoch 16/50, Train Loss 0.2587, Train Acc 0.9288, Test Loss 0.2845, Test Acc 0.9238
# Epoch [17/50], Batch [100/100], Loss 0.2345
# Epoch 17/50, Train Loss 0.2578, Train Acc 0.9294, Test Loss 0.2850, Test Acc 0.9235
# Epoch [18/50], Batch [100/100], Loss 0.2375
# Epoch 18/50, Train Loss 0.2564, Train Acc 0.9298, Test Loss 0.2847, Test Acc 0.9230
# Epoch [19/50], Batch [100/100], Loss 0.2679
# Epoch 19/50, Train Loss 0.2557, Train Acc 0.9300, Test Loss 0.2850, Test Acc 0.9240
# Epoch [20/50], Batch [100/100], Loss 0.2556
# Epoch 20/50, Train Loss 0.2548, Train Acc 0.9308, Test Loss 0.2850, Test Acc 0.9237
# Epoch [21/50], Batch [100/100], Loss 0.2330
# Epoch 21/50, Train Loss 0.2539, Train Acc 0.9306, Test Loss 0.2846, Test Acc 0.9236
# Epoch [22/50], Batch [100/100], Loss 0.2839
# Epoch 22/50, Train Loss 0.2533, Train Acc 0.9311, Test Loss 0.2858, Test Acc 0.9233
# Epoch [23/50], Batch [100/100], Loss 0.2930
# Epoch 23/50, Train Loss 0.2525, Train Acc 0.9314, Test Loss 0.2858, Test Acc 0.9231
# Epoch [24/50], Batch [100/100], Loss 0.2751
# Epoch 24/50, Train Loss 0.2517, Train Acc 0.9317, Test Loss 0.2854, Test Acc 0.9251
# Epoch [25/50], Batch [100/100], Loss 0.2461
# Epoch 25/50, Train Loss 0.2516, Train Acc 0.9316, Test Loss 0.2862, Test Acc 0.9237
# Epoch [26/50], Batch [100/100], Loss 0.2242
# Epoch 26/50, Train Loss 0.2505, Train Acc 0.9323, Test Loss 0.2855, Test Acc 0.9248
# Epoch [27/50], Batch [100/100], Loss 0.2180
# Epoch 27/50, Train Loss 0.2498, Train Acc 0.9319, Test Loss 0.2863, Test Acc 0.9238
# Epoch [28/50], Batch [100/100], Loss 0.2259
# Epoch 28/50, Train Loss 0.2494, Train Acc 0.9320, Test Loss 0.2863, Test Acc 0.9242
# Epoch [29/50], Batch [100/100], Loss 0.2346
# Epoch 29/50, Train Loss 0.2488, Train Acc 0.9327, Test Loss 0.2873, Test Acc 0.9241
# Epoch [30/50], Batch [100/100], Loss 0.2087
# Epoch 30/50, Train Loss 0.2485, Train Acc 0.9326, Test Loss 0.2871, Test Acc 0.9243
# Epoch [31/50], Batch [100/100], Loss 0.2548
# Epoch 31/50, Train Loss 0.2478, Train Acc 0.9330, Test Loss 0.2867, Test Acc 0.9234
# Epoch [32/50], Batch [100/100], Loss 0.2932
# Epoch 32/50, Train Loss 0.2473, Train Acc 0.9330, Test Loss 0.2878, Test Acc 0.9243
# Epoch [33/50], Batch [100/100], Loss 0.2630
# Epoch 33/50, Train Loss 0.2470, Train Acc 0.9330, Test Loss 0.2881, Test Acc 0.9240
# Epoch [34/50], Batch [100/100], Loss 0.2866
# Epoch 34/50, Train Loss 0.2466, Train Acc 0.9327, Test Loss 0.2877, Test Acc 0.9242
# Epoch [35/50], Batch [100/100], Loss 0.2962
# Epoch 35/50, Train Loss 0.2459, Train Acc 0.9333, Test Loss 0.2870, Test Acc 0.9237
# Epoch [36/50], Batch [100/100], Loss 0.2275
# Epoch 36/50, Train Loss 0.2461, Train Acc 0.9335, Test Loss 0.2881, Test Acc 0.9248
# Epoch [37/50], Batch [100/100], Loss 0.2848
# Epoch 37/50, Train Loss 0.2452, Train Acc 0.9333, Test Loss 0.2876, Test Acc 0.9243
# Epoch [38/50], Batch [100/100], Loss 0.2021
# Epoch 38/50, Train Loss 0.2450, Train Acc 0.9338, Test Loss 0.2885, Test Acc 0.9236
# Epoch [39/50], Batch [100/100], Loss 0.2424
# Epoch 39/50, Train Loss 0.2446, Train Acc 0.9334, Test Loss 0.2894, Test Acc 0.9236
# Epoch [40/50], Batch [100/100], Loss 0.1684
# Epoch 40/50, Train Loss 0.2442, Train Acc 0.9337, Test Loss 0.2883, Test Acc 0.9246
# Epoch [41/50], Batch [100/100], Loss 0.3221
# Epoch 41/50, Train Loss 0.2439, Train Acc 0.9339, Test Loss 0.2881, Test Acc 0.9238
# Epoch [42/50], Batch [100/100], Loss 0.2526
# Epoch 42/50, Train Loss 0.2436, Train Acc 0.9335, Test Loss 0.2892, Test Acc 0.9238
# Epoch [43/50], Batch [100/100], Loss 0.2466
# Epoch 43/50, Train Loss 0.2430, Train Acc 0.9340, Test Loss 0.2894, Test Acc 0.9243
# Epoch [44/50], Batch [100/100], Loss 0.2856
# Epoch 44/50, Train Loss 0.2427, Train Acc 0.9342, Test Loss 0.2898, Test Acc 0.9234
# Epoch [45/50], Batch [100/100], Loss 0.2788
# Epoch 45/50, Train Loss 0.2423, Train Acc 0.9338, Test Loss 0.2901, Test Acc 0.9241
# Epoch [46/50], Batch [100/100], Loss 0.2101
# Epoch 46/50, Train Loss 0.2424, Train Acc 0.9344, Test Loss 0.2909, Test Acc 0.9240
# Epoch [47/50], Batch [100/100], Loss 0.2229
# Epoch 47/50, Train Loss 0.2417, Train Acc 0.9342, Test Loss 0.2902, Test Acc 0.9242
# Epoch [48/50], Batch [100/100], Loss 0.2370
# Epoch 48/50, Train Loss 0.2415, Train Acc 0.9338, Test Loss 0.2907, Test Acc 0.9242
# Epoch [49/50], Batch [100/100], Loss 0.2355
# Epoch 49/50, Train Loss 0.2413, Train Acc 0.9345, Test Loss 0.2903, Test Acc 0.9239
# Epoch [50/50], Batch [100/100], Loss 0.2407
# Epoch 50/50, Train Loss 0.2413, Train Acc 0.9344, Test Loss 0.2913, Test Acc 0.9230

# %% [markdown]
# ## 7. Train model using the configuration "setting 3"

# %%
if __name__ == "__main__":

    cfg_idx = 'setting_3'
    
# configuration in setting 3:
#     {
#     "num_epoches" : 25,
#     "batch_size" : 100,
#     "learning_rate" : 0.1,
#     "learning_decay" : 0,
#     "decay_factor" : 0.75,
#     "momentum" : 0,
#     "lambda" : 0.00,
#     "mu" : 0.9
# }
    
    
    import logging
    logging.basicConfig(filename="./logs/{}.log".format(cfg_idx), filemode="w", format="%(message)s", level=logging.DEBUG)
    
    main(cfg_idx)
# Out:
# Epoch [1/25], Batch [100/600], Loss 0.2788
# Epoch [1/25], Batch [200/600], Loss 0.3185
# Epoch [1/25], Batch [300/600], Loss 0.2059
# Epoch [1/25], Batch [400/600], Loss 0.3359
# Epoch [1/25], Batch [500/600], Loss 0.3933
# Epoch [1/25], Batch [600/600], Loss 0.2960
# Epoch 1/25, Train Loss 0.3023, Train Acc 0.9188, Test Loss 0.3107, Test Acc 0.9167
# Epoch [2/25], Batch [100/600], Loss 0.1920
# Epoch [2/25], Batch [200/600], Loss 0.3029
# Epoch [2/25], Batch [300/600], Loss 0.2681
# Epoch [2/25], Batch [400/600], Loss 0.2246
# Epoch [2/25], Batch [500/600], Loss 0.2932
# Epoch [2/25], Batch [600/600], Loss 0.4400
# Epoch 2/25, Train Loss 0.2863, Train Acc 0.9222, Test Loss 0.3283, Test Acc 0.9203
# Epoch [3/25], Batch [100/600], Loss 0.3315
# Epoch [3/25], Batch [200/600], Loss 0.3344
# Epoch [3/25], Batch [300/600], Loss 0.3618
# Epoch [3/25], Batch [400/600], Loss 0.2833
# Epoch [3/25], Batch [500/600], Loss 0.1602
# Epoch [3/25], Batch [600/600], Loss 0.2737
# Epoch 3/25, Train Loss 0.2795, Train Acc 0.9253, Test Loss 0.3267, Test Acc 0.9231
# Epoch [4/25], Batch [100/600], Loss 0.5765
# Epoch [4/25], Batch [200/600], Loss 0.3132
# Epoch [4/25], Batch [300/600], Loss 0.3042
# Epoch [4/25], Batch [400/600], Loss 0.3279
# Epoch [4/25], Batch [500/600], Loss 0.3892
# Epoch [4/25], Batch [600/600], Loss 0.4057
# Epoch 4/25, Train Loss 0.2720, Train Acc 0.9264, Test Loss 0.3302, Test Acc 0.9197
# Epoch [5/25], Batch [100/600], Loss 0.2328
# Epoch [5/25], Batch [200/600], Loss 0.2600
# Epoch [5/25], Batch [300/600], Loss 0.4206
# Epoch [5/25], Batch [400/600], Loss 0.1872
# Epoch [5/25], Batch [500/600], Loss 0.2877
# Epoch [5/25], Batch [600/600], Loss 0.4286
# Epoch 5/25, Train Loss 0.2675, Train Acc 0.9273, Test Loss 0.3192, Test Acc 0.9214
# Epoch [6/25], Batch [100/600], Loss 0.1235
# Epoch [6/25], Batch [200/600], Loss 0.1508
# Epoch [6/25], Batch [300/600], Loss 0.3115
# Epoch [6/25], Batch [400/600], Loss 0.2141
# Epoch [6/25], Batch [500/600], Loss 0.2835
# Epoch [6/25], Batch [600/600], Loss 0.4125
# Epoch 6/25, Train Loss 0.2618, Train Acc 0.9284, Test Loss 0.3277, Test Acc 0.9220
# Epoch [7/25], Batch [100/600], Loss 0.1891
# Epoch [7/25], Batch [200/600], Loss 0.2361
# Epoch [7/25], Batch [300/600], Loss 0.3241
# Epoch [7/25], Batch [400/600], Loss 0.4004
# Epoch [7/25], Batch [500/600], Loss 0.3087
# Epoch [7/25], Batch [600/600], Loss 0.2481
# Epoch 7/25, Train Loss 0.2585, Train Acc 0.9298, Test Loss 0.3228, Test Acc 0.9238
# Epoch [8/25], Batch [100/600], Loss 0.3775
# Epoch [8/25], Batch [200/600], Loss 0.2116
# Epoch [8/25], Batch [300/600], Loss 0.3052
# Epoch [8/25], Batch [400/600], Loss 0.2481
# Epoch [8/25], Batch [500/600], Loss 0.3525
# Epoch [8/25], Batch [600/600], Loss 0.2143
# Epoch 8/25, Train Loss 0.2627, Train Acc 0.9304, Test Loss 0.3242, Test Acc 0.9231
# Epoch [9/25], Batch [100/600], Loss 0.2865
# Epoch [9/25], Batch [200/600], Loss 0.2775
# Epoch [9/25], Batch [300/600], Loss 0.2832
# Epoch [9/25], Batch [400/600], Loss 0.2446
# Epoch [9/25], Batch [500/600], Loss 0.2113
# Epoch [9/25], Batch [600/600], Loss 0.2750
# Epoch 9/25, Train Loss 0.2541, Train Acc 0.9324, Test Loss 0.3208, Test Acc 0.9243
# Epoch [10/25], Batch [100/600], Loss 0.1601
# Epoch [10/25], Batch [200/600], Loss 0.2080
# Epoch [10/25], Batch [300/600], Loss 0.2115
# Epoch [10/25], Batch [400/600], Loss 0.3483
# Epoch [10/25], Batch [500/600], Loss 0.2248
# Epoch [10/25], Batch [600/600], Loss 0.2140
# Epoch 10/25, Train Loss 0.2538, Train Acc 0.9326, Test Loss 0.3226, Test Acc 0.9208
# Epoch [11/25], Batch [100/600], Loss 0.1471
# Epoch [11/25], Batch [200/600], Loss 0.3443
# Epoch [11/25], Batch [300/600], Loss 0.4685
# Epoch [11/25], Batch [400/600], Loss 0.3976
# Epoch [11/25], Batch [500/600], Loss 0.1929
# Epoch [11/25], Batch [600/600], Loss 0.1221
# Epoch 11/25, Train Loss 0.2516, Train Acc 0.9323, Test Loss 0.3347, Test Acc 0.9216
# Epoch [12/25], Batch [100/600], Loss 0.3878
# Epoch [12/25], Batch [200/600], Loss 0.3116
# Epoch [12/25], Batch [300/600], Loss 0.1500
# Epoch [12/25], Batch [400/600], Loss 0.2352
# Epoch [12/25], Batch [500/600], Loss 0.1987
# Epoch [12/25], Batch [600/600], Loss 0.2337
# Epoch 12/25, Train Loss 0.2527, Train Acc 0.9321, Test Loss 0.3265, Test Acc 0.9214
# Epoch [13/25], Batch [100/600], Loss 0.3603
# Epoch [13/25], Batch [200/600], Loss 0.3001
# Epoch [13/25], Batch [300/600], Loss 0.6326
# Epoch [13/25], Batch [400/600], Loss 0.3086
# Epoch [13/25], Batch [500/600], Loss 0.2234
# Epoch [13/25], Batch [600/600], Loss 0.3829
# Epoch 13/25, Train Loss 0.2506, Train Acc 0.9318, Test Loss 0.3415, Test Acc 0.9222
# Epoch [14/25], Batch [100/600], Loss 0.4383
# Epoch [14/25], Batch [200/600], Loss 0.1927
# Epoch [14/25], Batch [300/600], Loss 0.3162
# Epoch [14/25], Batch [400/600], Loss 0.1389
# Epoch [14/25], Batch [500/600], Loss 0.3364
# Epoch [14/25], Batch [600/600], Loss 0.2867
# Epoch 14/25, Train Loss 0.2528, Train Acc 0.9335, Test Loss 0.3245, Test Acc 0.9241
# Epoch [15/25], Batch [100/600], Loss 0.1604
# Epoch [15/25], Batch [200/600], Loss 0.3194
# Epoch [15/25], Batch [300/600], Loss 0.2791
# Epoch [15/25], Batch [400/600], Loss 0.2038
# Epoch [15/25], Batch [500/600], Loss 0.1526
# Epoch [15/25], Batch [600/600], Loss 0.1953
# Epoch 15/25, Train Loss 0.2540, Train Acc 0.9318, Test Loss 0.3352, Test Acc 0.9201
# Epoch [16/25], Batch [100/600], Loss 0.3840
# Epoch [16/25], Batch [200/600], Loss 0.1292
# Epoch [16/25], Batch [300/600], Loss 0.3056
# Epoch [16/25], Batch [400/600], Loss 0.1200
# Epoch [16/25], Batch [500/600], Loss 0.3078
# Epoch [16/25], Batch [600/600], Loss 0.3045
# Epoch 16/25, Train Loss 0.2484, Train Acc 0.9328, Test Loss 0.3440, Test Acc 0.9230
# Epoch [17/25], Batch [100/600], Loss 0.1665
# Epoch [17/25], Batch [200/600], Loss 0.1652
# Epoch [17/25], Batch [300/600], Loss 0.3220
# Epoch [17/25], Batch [400/600], Loss 0.2454
# Epoch [17/25], Batch [500/600], Loss 0.2488
# Epoch [17/25], Batch [600/600], Loss 0.2671
# Epoch 17/25, Train Loss 0.2478, Train Acc 0.9326, Test Loss 0.3287, Test Acc 0.9216
# Epoch [18/25], Batch [100/600], Loss 0.2495
# Epoch [18/25], Batch [200/600], Loss 0.1931
# Epoch [18/25], Batch [300/600], Loss 0.3395
# Epoch [18/25], Batch [400/600], Loss 0.2001
# Epoch [18/25], Batch [500/600], Loss 0.2004
# Epoch [18/25], Batch [600/600], Loss 0.2312
# Epoch 18/25, Train Loss 0.2451, Train Acc 0.9345, Test Loss 0.3290, Test Acc 0.9227
# Epoch [19/25], Batch [100/600], Loss 0.1774
# Epoch [19/25], Batch [200/600], Loss 0.1997
# Epoch [19/25], Batch [300/600], Loss 0.2133
# Epoch [19/25], Batch [400/600], Loss 0.2144
# Epoch [19/25], Batch [500/600], Loss 0.2889
# Epoch [19/25], Batch [600/600], Loss 0.3963
# Epoch 19/25, Train Loss 0.2489, Train Acc 0.9335, Test Loss 0.3479, Test Acc 0.9225
# Epoch [20/25], Batch [100/600], Loss 0.1845
# Epoch [20/25], Batch [200/600], Loss 0.5716
# Epoch [20/25], Batch [300/600], Loss 0.2166
# Epoch [20/25], Batch [400/600], Loss 0.2651
# Epoch [20/25], Batch [500/600], Loss 0.2460
# Epoch [20/25], Batch [600/600], Loss 0.1550
# Epoch 20/25, Train Loss 0.2472, Train Acc 0.9331, Test Loss 0.3441, Test Acc 0.9221
# Epoch [21/25], Batch [100/600], Loss 0.1778
# Epoch [21/25], Batch [200/600], Loss 0.2056
# Epoch [21/25], Batch [300/600], Loss 0.3396
# Epoch [21/25], Batch [400/600], Loss 0.2723
# Epoch [21/25], Batch [500/600], Loss 0.2942
# Epoch [21/25], Batch [600/600], Loss 0.2136
# Epoch 21/25, Train Loss 0.2412, Train Acc 0.9347, Test Loss 0.3278, Test Acc 0.9230
# Epoch [22/25], Batch [100/600], Loss 0.2107
# Epoch [22/25], Batch [200/600], Loss 0.3160
# Epoch [22/25], Batch [300/600], Loss 0.1164
# Epoch [22/25], Batch [400/600], Loss 0.1820
# Epoch [22/25], Batch [500/600], Loss 0.3642
# Epoch [22/25], Batch [600/600], Loss 0.5497
# Epoch 22/25, Train Loss 0.2455, Train Acc 0.9345, Test Loss 0.3428, Test Acc 0.9207
# Epoch [23/25], Batch [100/600], Loss 0.4065
# Epoch [23/25], Batch [200/600], Loss 0.2651
# Epoch [23/25], Batch [300/600], Loss 0.4617
# Epoch [23/25], Batch [400/600], Loss 0.3840
# Epoch [23/25], Batch [500/600], Loss 0.1681
# Epoch [23/25], Batch [600/600], Loss 0.3305
# Epoch 23/25, Train Loss 0.2440, Train Acc 0.9354, Test Loss 0.3429, Test Acc 0.9228
# Epoch [24/25], Batch [100/600], Loss 0.2401
# Epoch [24/25], Batch [200/600], Loss 0.1892
# Epoch [24/25], Batch [300/600], Loss 0.2679
# Epoch [24/25], Batch [400/600], Loss 0.2261
# Epoch [24/25], Batch [500/600], Loss 0.2045
# Epoch [24/25], Batch [600/600], Loss 0.2801
# Epoch 24/25, Train Loss 0.2412, Train Acc 0.9357, Test Loss 0.3324, Test Acc 0.9253
# Epoch [25/25], Batch [100/600], Loss 0.1922
# Epoch [25/25], Batch [200/600], Loss 0.2190
# Epoch [25/25], Batch [300/600], Loss 0.1600
# Epoch [25/25], Batch [400/600], Loss 0.3026
# Epoch [25/25], Batch [500/600], Loss 0.1812
# Epoch [25/25], Batch [600/600], Loss 0.2530
# Epoch 25/25, Train Loss 0.2385, Train Acc 0.9350, Test Loss 0.3322, Test Acc 0.9225

# %% [markdown]
# ## 7. Train model using the configuration "setting 4"

# %%
if __name__ == "__main__":

    cfg_idx = 'setting_4'
    
# configuration in setting 4:
# {
#     "num_epoches" : 25,
#     "batch_size" : 100,
#     "learning_rate" : 0.01,
#     "learning_decay" : 0,
#     "decay_factor" : 0.75,
#     "momentum" : 0,
#     "lambda" : 0.00,
#     "mu" : 0.9
# }
    
    
    import logging
    logging.basicConfig(filename="./logs/{}.log".format(cfg_idx), filemode="w", format="%(message)s", level=logging.DEBUG)
    
    main(cfg_idx)
# Out:
# Epoch [1/25], Batch [100/600], Loss 0.6366
# Epoch [1/25], Batch [200/600], Loss 0.5569
# Epoch [1/25], Batch [300/600], Loss 0.3379
# Epoch [1/25], Batch [400/600], Loss 0.3936
# Epoch [1/25], Batch [500/600], Loss 0.3620
# Epoch [1/25], Batch [600/600], Loss 0.4071
# Epoch 1/25, Train Loss 0.3845, Train Acc 0.8962, Test Loss 0.3755, Test Acc 0.8986
# Epoch [2/25], Batch [100/600], Loss 0.3242
# Epoch [2/25], Batch [200/600], Loss 0.3705
# Epoch [2/25], Batch [300/600], Loss 0.2986
# Epoch [2/25], Batch [400/600], Loss 0.3251
# Epoch [2/25], Batch [500/600], Loss 0.2891
# Epoch [2/25], Batch [600/600], Loss 0.4402
# Epoch 2/25, Train Loss 0.3376, Train Acc 0.9061, Test Loss 0.3332, Test Acc 0.9072
# Epoch [3/25], Batch [100/600], Loss 0.4095
# Epoch [3/25], Batch [200/600], Loss 0.3669
# Epoch [3/25], Batch [300/600], Loss 0.4437
# Epoch [3/25], Batch [400/600], Loss 0.2949
# Epoch [3/25], Batch [500/600], Loss 0.1940
# Epoch [3/25], Batch [600/600], Loss 0.3255
# Epoch 3/25, Train Loss 0.3174, Train Acc 0.9113, Test Loss 0.3158, Test Acc 0.9108
# Epoch [4/25], Batch [100/600], Loss 0.3071
# Epoch [4/25], Batch [200/600], Loss 0.3334
# Epoch [4/25], Batch [300/600], Loss 0.3175
# Epoch [4/25], Batch [400/600], Loss 0.3488
# Epoch [4/25], Batch [500/600], Loss 0.3589
# Epoch [4/25], Batch [600/600], Loss 0.4239
# Epoch 4/25, Train Loss 0.3056, Train Acc 0.9143, Test Loss 0.3071, Test Acc 0.9134
# Epoch [5/25], Batch [100/600], Loss 0.2700
# Epoch [5/25], Batch [200/600], Loss 0.2599
# Epoch [5/25], Batch [300/600], Loss 0.4022
# Epoch [5/25], Batch [400/600], Loss 0.2327
# Epoch [5/25], Batch [500/600], Loss 0.3097
# Epoch [5/25], Batch [600/600], Loss 0.4620
# Epoch 5/25, Train Loss 0.2978, Train Acc 0.9162, Test Loss 0.3016, Test Acc 0.9145
# Epoch [6/25], Batch [100/600], Loss 0.1446
# Epoch [6/25], Batch [200/600], Loss 0.1803
# Epoch [6/25], Batch [300/600], Loss 0.3497
# Epoch [6/25], Batch [400/600], Loss 0.2621
# Epoch [6/25], Batch [500/600], Loss 0.2920
# Epoch [6/25], Batch [600/600], Loss 0.4051
# Epoch 6/25, Train Loss 0.2919, Train Acc 0.9182, Test Loss 0.2975, Test Acc 0.9165
# Epoch [7/25], Batch [100/600], Loss 0.2114
# Epoch [7/25], Batch [200/600], Loss 0.2817
# Epoch [7/25], Batch [300/600], Loss 0.3293
# Epoch [7/25], Batch [400/600], Loss 0.3267
# Epoch [7/25], Batch [500/600], Loss 0.3280
# Epoch [7/25], Batch [600/600], Loss 0.2459
# Epoch 7/25, Train Loss 0.2873, Train Acc 0.9193, Test Loss 0.2949, Test Acc 0.9174
# Epoch [8/25], Batch [100/600], Loss 0.3359
# Epoch [8/25], Batch [200/600], Loss 0.2640
# Epoch [8/25], Batch [300/600], Loss 0.2888
# Epoch [8/25], Batch [400/600], Loss 0.2527
# Epoch [8/25], Batch [500/600], Loss 0.3915
# Epoch [8/25], Batch [600/600], Loss 0.2546
# Epoch 8/25, Train Loss 0.2836, Train Acc 0.9209, Test Loss 0.2918, Test Acc 0.9190
# Epoch [9/25], Batch [100/600], Loss 0.3043
# Epoch [9/25], Batch [200/600], Loss 0.3635
# Epoch [9/25], Batch [300/600], Loss 0.3235
# Epoch [9/25], Batch [400/600], Loss 0.2617
# Epoch [9/25], Batch [500/600], Loss 0.2106
# Epoch [9/25], Batch [600/600], Loss 0.2582
# Epoch 9/25, Train Loss 0.2806, Train Acc 0.9217, Test Loss 0.2909, Test Acc 0.9195
# Epoch [10/25], Batch [100/600], Loss 0.1825
# Epoch [10/25], Batch [200/600], Loss 0.2280
# Epoch [10/25], Batch [300/600], Loss 0.2024
# Epoch [10/25], Batch [400/600], Loss 0.3140
# Epoch [10/25], Batch [500/600], Loss 0.2594
# Epoch [10/25], Batch [600/600], Loss 0.2482
# Epoch 10/25, Train Loss 0.2779, Train Acc 0.9221, Test Loss 0.2891, Test Acc 0.9201
# Epoch [11/25], Batch [100/600], Loss 0.2242
# Epoch [11/25], Batch [200/600], Loss 0.3547
# Epoch [11/25], Batch [300/600], Loss 0.4937
# Epoch [11/25], Batch [400/600], Loss 0.4229
# Epoch [11/25], Batch [500/600], Loss 0.2320
# Epoch [11/25], Batch [600/600], Loss 0.1114
# Epoch 11/25, Train Loss 0.2757, Train Acc 0.9228, Test Loss 0.2887, Test Acc 0.9203
# Epoch [12/25], Batch [100/600], Loss 0.4787
# Epoch [12/25], Batch [200/600], Loss 0.3533
# Epoch [12/25], Batch [300/600], Loss 0.1538
# Epoch [12/25], Batch [400/600], Loss 0.2594
# Epoch [12/25], Batch [500/600], Loss 0.2261
# Epoch [12/25], Batch [600/600], Loss 0.2586
# Epoch 12/25, Train Loss 0.2737, Train Acc 0.9234, Test Loss 0.2873, Test Acc 0.9210
# Epoch [13/25], Batch [100/600], Loss 0.3682
# Epoch [13/25], Batch [200/600], Loss 0.3022
# Epoch [13/25], Batch [300/600], Loss 0.6198
# Epoch [13/25], Batch [400/600], Loss 0.3062
# Epoch [13/25], Batch [500/600], Loss 0.2237
# Epoch [13/25], Batch [600/600], Loss 0.3304
# Epoch 13/25, Train Loss 0.2719, Train Acc 0.9244, Test Loss 0.2868, Test Acc 0.9219
# Epoch [14/25], Batch [100/600], Loss 0.3969
# Epoch [14/25], Batch [200/600], Loss 0.2041
# Epoch [14/25], Batch [300/600], Loss 0.2873
# Epoch [14/25], Batch [400/600], Loss 0.1482
# Epoch [14/25], Batch [500/600], Loss 0.3005
# Epoch [14/25], Batch [600/600], Loss 0.2785
# Epoch 14/25, Train Loss 0.2704, Train Acc 0.9249, Test Loss 0.2858, Test Acc 0.9219
# Epoch [15/25], Batch [100/600], Loss 0.1799
# Epoch [15/25], Batch [200/600], Loss 0.3213
# Epoch [15/25], Batch [300/600], Loss 0.3318
# Epoch [15/25], Batch [400/600], Loss 0.2214
# Epoch [15/25], Batch [500/600], Loss 0.1443
# Epoch [15/25], Batch [600/600], Loss 0.2454
# Epoch 15/25, Train Loss 0.2691, Train Acc 0.9251, Test Loss 0.2862, Test Acc 0.9211
# Epoch [16/25], Batch [100/600], Loss 0.3658
# Epoch [16/25], Batch [200/600], Loss 0.1697
# Epoch [16/25], Batch [300/600], Loss 0.3567
# Epoch [16/25], Batch [400/600], Loss 0.1491
# Epoch [16/25], Batch [500/600], Loss 0.3049
# Epoch [16/25], Batch [600/600], Loss 0.3260
# Epoch 16/25, Train Loss 0.2676, Train Acc 0.9254, Test Loss 0.2852, Test Acc 0.9234
# Epoch [17/25], Batch [100/600], Loss 0.2088
# Epoch [17/25], Batch [200/600], Loss 0.1675
# Epoch [17/25], Batch [300/600], Loss 0.3172
# Epoch [17/25], Batch [400/600], Loss 0.2454
# Epoch [17/25], Batch [500/600], Loss 0.2194
# Epoch [17/25], Batch [600/600], Loss 0.1668
# Epoch 17/25, Train Loss 0.2665, Train Acc 0.9264, Test Loss 0.2852, Test Acc 0.9223
# Epoch [18/25], Batch [100/600], Loss 0.2854
# Epoch [18/25], Batch [200/600], Loss 0.2459
# Epoch [18/25], Batch [300/600], Loss 0.2041
# Epoch [18/25], Batch [400/600], Loss 0.2460
# Epoch [18/25], Batch [500/600], Loss 0.2148
# Epoch [18/25], Batch [600/600], Loss 0.2530
# Epoch 18/25, Train Loss 0.2653, Train Acc 0.9269, Test Loss 0.2850, Test Acc 0.9226
# Epoch [19/25], Batch [100/600], Loss 0.2106
# Epoch [19/25], Batch [200/600], Loss 0.2468
# Epoch [19/25], Batch [300/600], Loss 0.2309
# Epoch [19/25], Batch [400/600], Loss 0.1989
# Epoch [19/25], Batch [500/600], Loss 0.2988
# Epoch [19/25], Batch [600/600], Loss 0.3688
# Epoch 19/25, Train Loss 0.2642, Train Acc 0.9271, Test Loss 0.2848, Test Acc 0.9233
# Epoch [20/25], Batch [100/600], Loss 0.2192
# Epoch [20/25], Batch [200/600], Loss 0.5349
# Epoch [20/25], Batch [300/600], Loss 0.2790
# Epoch [20/25], Batch [400/600], Loss 0.2688
# Epoch [20/25], Batch [500/600], Loss 0.2206
# Epoch [20/25], Batch [600/600], Loss 0.1809
# Epoch 20/25, Train Loss 0.2633, Train Acc 0.9275, Test Loss 0.2846, Test Acc 0.9236
# Epoch [21/25], Batch [100/600], Loss 0.1966
# Epoch [21/25], Batch [200/600], Loss 0.2280
# Epoch [21/25], Batch [300/600], Loss 0.3351
# Epoch [21/25], Batch [400/600], Loss 0.2922
# Epoch [21/25], Batch [500/600], Loss 0.3152
# Epoch [21/25], Batch [600/600], Loss 0.2079
# Epoch 21/25, Train Loss 0.2624, Train Acc 0.9278, Test Loss 0.2840, Test Acc 0.9236
# Epoch [22/25], Batch [100/600], Loss 0.2265
# Epoch [22/25], Batch [200/600], Loss 0.3216
# Epoch [22/25], Batch [300/600], Loss 0.1704
# Epoch [22/25], Batch [400/600], Loss 0.2199
# Epoch [22/25], Batch [500/600], Loss 0.2820
# Epoch [22/25], Batch [600/600], Loss 0.2795
# Epoch 22/25, Train Loss 0.2615, Train Acc 0.9280, Test Loss 0.2844, Test Acc 0.9235
# Epoch [23/25], Batch [100/600], Loss 0.4718
# Epoch [23/25], Batch [200/600], Loss 0.3041
# Epoch [23/25], Batch [300/600], Loss 0.4056
# Epoch [23/25], Batch [400/600], Loss 0.3867
# Epoch [23/25], Batch [500/600], Loss 0.2152
# Epoch [23/25], Batch [600/600], Loss 0.2504
# Epoch 23/25, Train Loss 0.2607, Train Acc 0.9285, Test Loss 0.2845, Test Acc 0.9237
# Epoch [24/25], Batch [100/600], Loss 0.2710
# Epoch [24/25], Batch [200/600], Loss 0.2668
# Epoch [24/25], Batch [300/600], Loss 0.3118
# Epoch [24/25], Batch [400/600], Loss 0.2374
# Epoch [24/25], Batch [500/600], Loss 0.1791
# Epoch [24/25], Batch [600/600], Loss 0.2810
# Epoch 24/25, Train Loss 0.2599, Train Acc 0.9287, Test Loss 0.2842, Test Acc 0.9241
# Epoch [25/25], Batch [100/600], Loss 0.2253
# Epoch [25/25], Batch [200/600], Loss 0.2293
# Epoch [25/25], Batch [300/600], Loss 0.1720
# Epoch [25/25], Batch [400/600], Loss 0.3258
# Epoch [25/25], Batch [500/600], Loss 0.1996
# Epoch [25/25], Batch [600/600], Loss 0.2447
# Epoch 25/25, Train Loss 0.2594, Train Acc 0.9288, Test Loss 0.2845, Test Acc 0.9240

# %% [markdown]
# ## 7. Train model using the configuration "setting 5"

# %%
if __name__ == "__main__":

    cfg_idx = 'setting_5'
    
# configuration in setting 5:
#     {
#     "num_epoches" : 50,
#     "batch_size" : 600,
#     "learning_rate" : 0.1,
#     "learning_decay" : 0,
#     "decay_factor" : 0.75,
#     "momentum" : 0,
#     "lambda" : 0.001,
#     "mu" : 0.9
# }
    
    
    import logging
    logging.basicConfig(filename="./logs/{}.log".format(cfg_idx), filemode="w", format="%(message)s", level=logging.DEBUG)
    
    main(cfg_idx)
# Out:
# Epoch [1/50], Batch [100/100], Loss 0.3143
# Epoch 1/50, Train Loss 0.3519, Train Acc 0.9040, Test Loss 0.3463, Test Acc 0.9049
# Epoch [2/50], Batch [100/100], Loss 0.3327
# Epoch 2/50, Train Loss 0.3185, Train Acc 0.9120, Test Loss 0.3184, Test Acc 0.9123
# Epoch [3/50], Batch [100/100], Loss 0.3020
# Epoch 3/50, Train Loss 0.3043, Train Acc 0.9165, Test Loss 0.3071, Test Acc 0.9158
# Epoch [4/50], Batch [100/100], Loss 0.2706
# Epoch 4/50, Train Loss 0.2961, Train Acc 0.9189, Test Loss 0.3027, Test Acc 0.9165
# Epoch [5/50], Batch [100/100], Loss 0.2393
# Epoch 5/50, Train Loss 0.2909, Train Acc 0.9206, Test Loss 0.3002, Test Acc 0.9183
# Epoch [6/50], Batch [100/100], Loss 0.2905
# Epoch 6/50, Train Loss 0.2867, Train Acc 0.9215, Test Loss 0.2980, Test Acc 0.9200
# Epoch [7/50], Batch [100/100], Loss 0.2137
# Epoch 7/50, Train Loss 0.2836, Train Acc 0.9225, Test Loss 0.2967, Test Acc 0.9199
# Epoch [8/50], Batch [100/100], Loss 0.2358
# Epoch 8/50, Train Loss 0.2815, Train Acc 0.9239, Test Loss 0.2953, Test Acc 0.9215
# Epoch [9/50], Batch [100/100], Loss 0.2483
# Epoch 9/50, Train Loss 0.2793, Train Acc 0.9248, Test Loss 0.2958, Test Acc 0.9216
# Epoch [10/50], Batch [100/100], Loss 0.2621
# Epoch 10/50, Train Loss 0.2778, Train Acc 0.9255, Test Loss 0.2942, Test Acc 0.9225
# Epoch [11/50], Batch [100/100], Loss 0.2688
# Epoch 11/50, Train Loss 0.2762, Train Acc 0.9255, Test Loss 0.2955, Test Acc 0.9219
# Epoch [12/50], Batch [100/100], Loss 0.2908
# Epoch 12/50, Train Loss 0.2750, Train Acc 0.9261, Test Loss 0.2945, Test Acc 0.9228
# Epoch [13/50], Batch [100/100], Loss 0.3282
# Epoch 13/50, Train Loss 0.2739, Train Acc 0.9270, Test Loss 0.2948, Test Acc 0.9225
# Epoch [14/50], Batch [100/100], Loss 0.2432
# Epoch 14/50, Train Loss 0.2730, Train Acc 0.9275, Test Loss 0.2941, Test Acc 0.9233
# Epoch [15/50], Batch [100/100], Loss 0.2657
# Epoch 15/50, Train Loss 0.2725, Train Acc 0.9273, Test Loss 0.2956, Test Acc 0.9227
# Epoch [16/50], Batch [100/100], Loss 0.2761
# Epoch 16/50, Train Loss 0.2715, Train Acc 0.9277, Test Loss 0.2948, Test Acc 0.9235
# Epoch [17/50], Batch [100/100], Loss 0.2376
# Epoch 17/50, Train Loss 0.2709, Train Acc 0.9286, Test Loss 0.2954, Test Acc 0.9234
# Epoch [18/50], Batch [100/100], Loss 0.2404
# Epoch 18/50, Train Loss 0.2698, Train Acc 0.9287, Test Loss 0.2952, Test Acc 0.9229
# Epoch [19/50], Batch [100/100], Loss 0.2711
# Epoch 19/50, Train Loss 0.2694, Train Acc 0.9292, Test Loss 0.2956, Test Acc 0.9239
# Epoch [20/50], Batch [100/100], Loss 0.2571
# Epoch 20/50, Train Loss 0.2689, Train Acc 0.9299, Test Loss 0.2957, Test Acc 0.9235
# Epoch [21/50], Batch [100/100], Loss 0.2374
# Epoch 21/50, Train Loss 0.2683, Train Acc 0.9297, Test Loss 0.2954, Test Acc 0.9238
# Epoch [22/50], Batch [100/100], Loss 0.2874
# Epoch 22/50, Train Loss 0.2679, Train Acc 0.9300, Test Loss 0.2968, Test Acc 0.9231
# Epoch [23/50], Batch [100/100], Loss 0.2953
# Epoch 23/50, Train Loss 0.2674, Train Acc 0.9304, Test Loss 0.2968, Test Acc 0.9230
# Epoch [24/50], Batch [100/100], Loss 0.2780
# Epoch 24/50, Train Loss 0.2669, Train Acc 0.9304, Test Loss 0.2965, Test Acc 0.9241
# Epoch [25/50], Batch [100/100], Loss 0.2493
# Epoch 25/50, Train Loss 0.2671, Train Acc 0.9304, Test Loss 0.2973, Test Acc 0.9235
# Epoch [26/50], Batch [100/100], Loss 0.2295
# Epoch 26/50, Train Loss 0.2663, Train Acc 0.9312, Test Loss 0.2967, Test Acc 0.9244
# Epoch [27/50], Batch [100/100], Loss 0.2214
# Epoch 27/50, Train Loss 0.2659, Train Acc 0.9309, Test Loss 0.2976, Test Acc 0.9238
# Epoch [28/50], Batch [100/100], Loss 0.2277
# Epoch 28/50, Train Loss 0.2658, Train Acc 0.9310, Test Loss 0.2975, Test Acc 0.9239
# Epoch [29/50], Batch [100/100], Loss 0.2416
# Epoch 29/50, Train Loss 0.2654, Train Acc 0.9315, Test Loss 0.2986, Test Acc 0.9237
# Epoch [30/50], Batch [100/100], Loss 0.2136
# Epoch 30/50, Train Loss 0.2654, Train Acc 0.9312, Test Loss 0.2984, Test Acc 0.9241
# Epoch [31/50], Batch [100/100], Loss 0.2588
# Epoch 31/50, Train Loss 0.2648, Train Acc 0.9317, Test Loss 0.2980, Test Acc 0.9236
# Epoch [32/50], Batch [100/100], Loss 0.2945
# Epoch 32/50, Train Loss 0.2647, Train Acc 0.9315, Test Loss 0.2992, Test Acc 0.9244
# Epoch [33/50], Batch [100/100], Loss 0.2677
# Epoch 33/50, Train Loss 0.2646, Train Acc 0.9313, Test Loss 0.2996, Test Acc 0.9236
# Epoch [34/50], Batch [100/100], Loss 0.2906
# Epoch 34/50, Train Loss 0.2644, Train Acc 0.9317, Test Loss 0.2992, Test Acc 0.9237
# Epoch [35/50], Batch [100/100], Loss 0.2986
# Epoch 35/50, Train Loss 0.2640, Train Acc 0.9317, Test Loss 0.2984, Test Acc 0.9237
# Epoch [36/50], Batch [100/100], Loss 0.2333
# Epoch 36/50, Train Loss 0.2644, Train Acc 0.9322, Test Loss 0.2995, Test Acc 0.9251
# Epoch [37/50], Batch [100/100], Loss 0.2873
# Epoch 37/50, Train Loss 0.2637, Train Acc 0.9317, Test Loss 0.2991, Test Acc 0.9237
# Epoch [38/50], Batch [100/100], Loss 0.2083
# Epoch 38/50, Train Loss 0.2637, Train Acc 0.9321, Test Loss 0.2999, Test Acc 0.9238
# Epoch [39/50], Batch [100/100], Loss 0.2472
# Epoch 39/50, Train Loss 0.2635, Train Acc 0.9319, Test Loss 0.3009, Test Acc 0.9230
# Epoch [40/50], Batch [100/100], Loss 0.1760
# Epoch 40/50, Train Loss 0.2634, Train Acc 0.9323, Test Loss 0.2998, Test Acc 0.9240
# Epoch [41/50], Batch [100/100], Loss 0.3255
# Epoch 41/50, Train Loss 0.2633, Train Acc 0.9322, Test Loss 0.2995, Test Acc 0.9234
# Epoch [42/50], Batch [100/100], Loss 0.2586
# Epoch 42/50, Train Loss 0.2632, Train Acc 0.9325, Test Loss 0.3008, Test Acc 0.9235
# Epoch [43/50], Batch [100/100], Loss 0.2535
# Epoch 43/50, Train Loss 0.2628, Train Acc 0.9324, Test Loss 0.3009, Test Acc 0.9246
# Epoch [44/50], Batch [100/100], Loss 0.2880
# Epoch 44/50, Train Loss 0.2627, Train Acc 0.9324, Test Loss 0.3012, Test Acc 0.9242
# Epoch [45/50], Batch [100/100], Loss 0.2846
# Epoch 45/50, Train Loss 0.2625, Train Acc 0.9327, Test Loss 0.3014, Test Acc 0.9235
# Epoch [46/50], Batch [100/100], Loss 0.2169
# Epoch 46/50, Train Loss 0.2629, Train Acc 0.9325, Test Loss 0.3023, Test Acc 0.9237
# Epoch [47/50], Batch [100/100], Loss 0.2300
# Epoch 47/50, Train Loss 0.2623, Train Acc 0.9327, Test Loss 0.3015, Test Acc 0.9239
# Epoch [48/50], Batch [100/100], Loss 0.2447
# Epoch 48/50, Train Loss 0.2623, Train Acc 0.9324, Test Loss 0.3021, Test Acc 0.9243
# Epoch [49/50], Batch [100/100], Loss 0.2396
# Epoch 49/50, Train Loss 0.2623, Train Acc 0.9327, Test Loss 0.3016, Test Acc 0.9240
# Epoch [50/50], Batch [100/100], Loss 0.2461
# Epoch 50/50, Train Loss 0.2625, Train Acc 0.9330, Test Loss 0.3026, Test Acc 0.9237

# %% [markdown]
# ## 7. Train model using the configuration "setting 6"

# %%
if __name__ == "__main__":

    cfg_idx = 'setting_6'
    
# configuration in setting 6:
#     {
#     "num_epoches" : 50,
#     "batch_size" : 600,
#     "learning_rate" : 0.1,
#     "learning_decay" : 0,
#     "decay_factor" : 0.75,
#     "momentum" : 0,
#     "lambda" : 0.01,
#     "mu" : 0.9
# }
    
    import logging
    logging.basicConfig(filename="./logs/{}.log".format(cfg_idx), filemode="w", format="%(message)s", level=logging.DEBUG)
    
    main(cfg_idx)
# Out:
# Epoch [1/50], Batch [100/100], Loss 0.3215
# Epoch 1/50, Train Loss 0.3826, Train Acc 0.9032, Test Loss 0.3764, Test Acc 0.9041
# Epoch [2/50], Batch [100/100], Loss 0.3399
# Epoch 2/50, Train Loss 0.3596, Train Acc 0.9110, Test Loss 0.3582, Test Acc 0.9115
# Epoch [3/50], Batch [100/100], Loss 0.3162
# Epoch 3/50, Train Loss 0.3520, Train Acc 0.9147, Test Loss 0.3525, Test Acc 0.9141
# Epoch [4/50], Batch [100/100], Loss 0.2864
# Epoch 4/50, Train Loss 0.3487, Train Acc 0.9163, Test Loss 0.3520, Test Acc 0.9156
# Epoch [5/50], Batch [100/100], Loss 0.2564
# Epoch 5/50, Train Loss 0.3468, Train Acc 0.9180, Test Loss 0.3520, Test Acc 0.9161
# Epoch [6/50], Batch [100/100], Loss 0.3031
# Epoch 6/50, Train Loss 0.3455, Train Acc 0.9184, Test Loss 0.3517, Test Acc 0.9170
# Epoch [7/50], Batch [100/100], Loss 0.2367
# Epoch 7/50, Train Loss 0.3449, Train Acc 0.9193, Test Loss 0.3517, Test Acc 0.9172
# Epoch [8/50], Batch [100/100], Loss 0.2605
# Epoch 8/50, Train Loss 0.3446, Train Acc 0.9198, Test Loss 0.3511, Test Acc 0.9183
# Epoch [9/50], Batch [100/100], Loss 0.2671
# Epoch 9/50, Train Loss 0.3440, Train Acc 0.9208, Test Loss 0.3525, Test Acc 0.9185
# Epoch [10/50], Batch [100/100], Loss 0.2786
# Epoch 10/50, Train Loss 0.3439, Train Acc 0.9207, Test Loss 0.3516, Test Acc 0.9191
# Epoch [11/50], Batch [100/100], Loss 0.2860
# Epoch 11/50, Train Loss 0.3438, Train Acc 0.9203, Test Loss 0.3529, Test Acc 0.9178
# Epoch [12/50], Batch [100/100], Loss 0.3087
# Epoch 12/50, Train Loss 0.3437, Train Acc 0.9209, Test Loss 0.3525, Test Acc 0.9187
# Epoch [13/50], Batch [100/100], Loss 0.3547
# Epoch 13/50, Train Loss 0.3435, Train Acc 0.9214, Test Loss 0.3530, Test Acc 0.9181
# Epoch [14/50], Batch [100/100], Loss 0.2688
# Epoch 14/50, Train Loss 0.3436, Train Acc 0.9221, Test Loss 0.3521, Test Acc 0.9184
# Epoch [15/50], Batch [100/100], Loss 0.2881
# Epoch 15/50, Train Loss 0.3439, Train Acc 0.9214, Test Loss 0.3535, Test Acc 0.9162
# Epoch [16/50], Batch [100/100], Loss 0.3034
# Epoch 16/50, Train Loss 0.3436, Train Acc 0.9213, Test Loss 0.3531, Test Acc 0.9193
# Epoch [17/50], Batch [100/100], Loss 0.2650
# Epoch 17/50, Train Loss 0.3438, Train Acc 0.9213, Test Loss 0.3537, Test Acc 0.9186
# Epoch [18/50], Batch [100/100], Loss 0.2685
# Epoch 18/50, Train Loss 0.3432, Train Acc 0.9221, Test Loss 0.3533, Test Acc 0.9194
# Epoch [19/50], Batch [100/100], Loss 0.3011
# Epoch 19/50, Train Loss 0.3436, Train Acc 0.9213, Test Loss 0.3533, Test Acc 0.9190
# Epoch [20/50], Batch [100/100], Loss 0.2771
# Epoch 20/50, Train Loss 0.3433, Train Acc 0.9219, Test Loss 0.3535, Test Acc 0.9191
# Epoch [21/50], Batch [100/100], Loss 0.2740
# Epoch 21/50, Train Loss 0.3433, Train Acc 0.9222, Test Loss 0.3533, Test Acc 0.9188
# Epoch [22/50], Batch [100/100], Loss 0.3201
# Epoch 22/50, Train Loss 0.3434, Train Acc 0.9225, Test Loss 0.3547, Test Acc 0.9191
# Epoch [23/50], Batch [100/100], Loss 0.3224
# Epoch 23/50, Train Loss 0.3432, Train Acc 0.9219, Test Loss 0.3543, Test Acc 0.9189
# Epoch [24/50], Batch [100/100], Loss 0.3081
# Epoch 24/50, Train Loss 0.3431, Train Acc 0.9217, Test Loss 0.3539, Test Acc 0.9183
# Epoch [25/50], Batch [100/100], Loss 0.2811
# Epoch 25/50, Train Loss 0.3438, Train Acc 0.9215, Test Loss 0.3547, Test Acc 0.9191
# Epoch [26/50], Batch [100/100], Loss 0.2695
# Epoch 26/50, Train Loss 0.3434, Train Acc 0.9224, Test Loss 0.3539, Test Acc 0.9197
# Epoch [27/50], Batch [100/100], Loss 0.2494
# Epoch 27/50, Train Loss 0.3433, Train Acc 0.9221, Test Loss 0.3548, Test Acc 0.9180
# Epoch [28/50], Batch [100/100], Loss 0.2543
# Epoch 28/50, Train Loss 0.3433, Train Acc 0.9221, Test Loss 0.3536, Test Acc 0.9181
# Epoch [29/50], Batch [100/100], Loss 0.2882
# Epoch 29/50, Train Loss 0.3431, Train Acc 0.9221, Test Loss 0.3550, Test Acc 0.9182
# Epoch [30/50], Batch [100/100], Loss 0.2521
# Epoch 30/50, Train Loss 0.3434, Train Acc 0.9219, Test Loss 0.3542, Test Acc 0.9180
# Epoch [31/50], Batch [100/100], Loss 0.2930
# Epoch 31/50, Train Loss 0.3432, Train Acc 0.9224, Test Loss 0.3540, Test Acc 0.9195
# Epoch [32/50], Batch [100/100], Loss 0.3172
# Epoch 32/50, Train Loss 0.3432, Train Acc 0.9223, Test Loss 0.3550, Test Acc 0.9191
# Epoch [33/50], Batch [100/100], Loss 0.3056
# Epoch 33/50, Train Loss 0.3435, Train Acc 0.9220, Test Loss 0.3550, Test Acc 0.9185
# Epoch [34/50], Batch [100/100], Loss 0.3319
# Epoch 34/50, Train Loss 0.3435, Train Acc 0.9225, Test Loss 0.3542, Test Acc 0.9190
# Epoch [35/50], Batch [100/100], Loss 0.3277
# Epoch 35/50, Train Loss 0.3432, Train Acc 0.9222, Test Loss 0.3535, Test Acc 0.9182
# Epoch [36/50], Batch [100/100], Loss 0.2744
# Epoch 36/50, Train Loss 0.3437, Train Acc 0.9225, Test Loss 0.3542, Test Acc 0.9206
# Epoch [37/50], Batch [100/100], Loss 0.3205
# Epoch 37/50, Train Loss 0.3431, Train Acc 0.9221, Test Loss 0.3538, Test Acc 0.9192
# Epoch [38/50], Batch [100/100], Loss 0.2485
# Epoch 38/50, Train Loss 0.3432, Train Acc 0.9227, Test Loss 0.3541, Test Acc 0.9187
# Epoch [39/50], Batch [100/100], Loss 0.2808
# Epoch 39/50, Train Loss 0.3433, Train Acc 0.9221, Test Loss 0.3551, Test Acc 0.9179
# Epoch [40/50], Batch [100/100], Loss 0.2210
# Epoch 40/50, Train Loss 0.3433, Train Acc 0.9219, Test Loss 0.3542, Test Acc 0.9184
# Epoch [41/50], Batch [100/100], Loss 0.3596
# Epoch 41/50, Train Loss 0.3433, Train Acc 0.9219, Test Loss 0.3536, Test Acc 0.9193
# Epoch [42/50], Batch [100/100], Loss 0.3001
# Epoch 42/50, Train Loss 0.3434, Train Acc 0.9223, Test Loss 0.3548, Test Acc 0.9189
# Epoch [43/50], Batch [100/100], Loss 0.2964
# Epoch 43/50, Train Loss 0.3432, Train Acc 0.9223, Test Loss 0.3547, Test Acc 0.9185
# Epoch [44/50], Batch [100/100], Loss 0.3124
# Epoch 44/50, Train Loss 0.3431, Train Acc 0.9218, Test Loss 0.3545, Test Acc 0.9182
# Epoch [45/50], Batch [100/100], Loss 0.3290
# Epoch 45/50, Train Loss 0.3431, Train Acc 0.9219, Test Loss 0.3548, Test Acc 0.9191
# Epoch [46/50], Batch [100/100], Loss 0.2587
# Epoch 46/50, Train Loss 0.3438, Train Acc 0.9221, Test Loss 0.3560, Test Acc 0.9188
# Epoch [47/50], Batch [100/100], Loss 0.2719
# Epoch 47/50, Train Loss 0.3431, Train Acc 0.9221, Test Loss 0.3541, Test Acc 0.9190
# Epoch [48/50], Batch [100/100], Loss 0.2897
# Epoch 48/50, Train Loss 0.3431, Train Acc 0.9223, Test Loss 0.3547, Test Acc 0.9188
# Epoch [49/50], Batch [100/100], Loss 0.2773
# Epoch 49/50, Train Loss 0.3432, Train Acc 0.9222, Test Loss 0.3539, Test Acc 0.9187
# Epoch [50/50], Batch [100/100], Loss 0.2844
# Epoch 50/50, Train Loss 0.3435, Train Acc 0.9217, Test Loss 0.3547, Test Acc 0.9183

# %% [markdown]
# ## 7. Train model using the configuration "setting 7"

# %%
if __name__ == "__main__":

    cfg_idx = 'setting_7'
    
# configuration in setting 7:
#     {
#     "num_epoches" : 50,
#     "batch_size" : 600,
#     "learning_rate" : 0.1,
#     "learning_decay" : 0,
#     "decay_factor" : 0.75,
#     "momentum" : 0,
#     "lambda" : 0.1,
#     "mu" : 0.9
# }
    
    
    import logging
    logging.basicConfig(filename="./logs/{}.log".format(cfg_idx), filemode="w", format="%(message)s", level=logging.DEBUG)
    
    main(cfg_idx)
# Out:
# Epoch [1/50], Batch [100/100], Loss 0.3983
# Epoch 1/50, Train Loss 0.5859, Train Acc 0.8959, Test Loss 0.5755, Test Acc 0.8975
# Epoch [2/50], Batch [100/100], Loss 0.4247
# Epoch 2/50, Train Loss 0.5844, Train Acc 0.8985, Test Loss 0.5756, Test Acc 0.9012
# Epoch [3/50], Batch [100/100], Loss 0.4407
# Epoch 3/50, Train Loss 0.5846, Train Acc 0.8994, Test Loss 0.5747, Test Acc 0.9011
# Epoch [4/50], Batch [100/100], Loss 0.4100
# Epoch 4/50, Train Loss 0.5848, Train Acc 0.8988, Test Loss 0.5760, Test Acc 0.9008
# Epoch [5/50], Batch [100/100], Loss 0.3810
# Epoch 5/50, Train Loss 0.5848, Train Acc 0.8985, Test Loss 0.5759, Test Acc 0.9004
# Epoch [6/50], Batch [100/100], Loss 0.4184
# Epoch 6/50, Train Loss 0.5843, Train Acc 0.8987, Test Loss 0.5750, Test Acc 0.9007
# Epoch [7/50], Batch [100/100], Loss 0.3753
# Epoch 7/50, Train Loss 0.5846, Train Acc 0.8990, Test Loss 0.5750, Test Acc 0.8994
# Epoch [8/50], Batch [100/100], Loss 0.4022
# Epoch 8/50, Train Loss 0.5852, Train Acc 0.8986, Test Loss 0.5744, Test Acc 0.9001
# Epoch [9/50], Batch [100/100], Loss 0.3892
# Epoch 9/50, Train Loss 0.5840, Train Acc 0.8992, Test Loss 0.5748, Test Acc 0.9010
# Epoch [10/50], Batch [100/100], Loss 0.3992
# Epoch 10/50, Train Loss 0.5848, Train Acc 0.8997, Test Loss 0.5744, Test Acc 0.9019
# Epoch [11/50], Batch [100/100], Loss 0.3958
# Epoch 11/50, Train Loss 0.5846, Train Acc 0.8987, Test Loss 0.5747, Test Acc 0.9020
# Epoch [12/50], Batch [100/100], Loss 0.4405
# Epoch 12/50, Train Loss 0.5848, Train Acc 0.8984, Test Loss 0.5757, Test Acc 0.9007
# Epoch [13/50], Batch [100/100], Loss 0.4861
# Epoch 13/50, Train Loss 0.5847, Train Acc 0.9001, Test Loss 0.5753, Test Acc 0.9004
# Epoch [14/50], Batch [100/100], Loss 0.3982
# Epoch 14/50, Train Loss 0.5850, Train Acc 0.8996, Test Loss 0.5741, Test Acc 0.9022
# Epoch [15/50], Batch [100/100], Loss 0.4051
# Epoch 15/50, Train Loss 0.5848, Train Acc 0.8978, Test Loss 0.5744, Test Acc 0.9003
# Epoch [16/50], Batch [100/100], Loss 0.4346
# Epoch 16/50, Train Loss 0.5847, Train Acc 0.8995, Test Loss 0.5745, Test Acc 0.9017
# Epoch [17/50], Batch [100/100], Loss 0.3937
# Epoch 17/50, Train Loss 0.5851, Train Acc 0.8995, Test Loss 0.5760, Test Acc 0.9015
# Epoch [18/50], Batch [100/100], Loss 0.4046
# Epoch 18/50, Train Loss 0.5845, Train Acc 0.8995, Test Loss 0.5748, Test Acc 0.9013
# Epoch [19/50], Batch [100/100], Loss 0.4359
# Epoch 19/50, Train Loss 0.5847, Train Acc 0.8996, Test Loss 0.5745, Test Acc 0.9011
# Epoch [20/50], Batch [100/100], Loss 0.3922
# Epoch 20/50, Train Loss 0.5845, Train Acc 0.8996, Test Loss 0.5743, Test Acc 0.9014
# Epoch [21/50], Batch [100/100], Loss 0.4136
# Epoch 21/50, Train Loss 0.5843, Train Acc 0.9001, Test Loss 0.5750, Test Acc 0.9006
# Epoch [22/50], Batch [100/100], Loss 0.4562
# Epoch 22/50, Train Loss 0.5853, Train Acc 0.9002, Test Loss 0.5770, Test Acc 0.9007
# Epoch [23/50], Batch [100/100], Loss 0.4483
# Epoch 23/50, Train Loss 0.5846, Train Acc 0.8996, Test Loss 0.5755, Test Acc 0.9010
# Epoch [24/50], Batch [100/100], Loss 0.4496
# Epoch 24/50, Train Loss 0.5843, Train Acc 0.9005, Test Loss 0.5747, Test Acc 0.9035
# Epoch [25/50], Batch [100/100], Loss 0.4206
# Epoch 25/50, Train Loss 0.5849, Train Acc 0.8992, Test Loss 0.5758, Test Acc 0.9012
# Epoch [26/50], Batch [100/100], Loss 0.4130
# Epoch 26/50, Train Loss 0.5849, Train Acc 0.9002, Test Loss 0.5738, Test Acc 0.9021
# Epoch [27/50], Batch [100/100], Loss 0.3724
# Epoch 27/50, Train Loss 0.5847, Train Acc 0.8993, Test Loss 0.5757, Test Acc 0.9010
# Epoch [28/50], Batch [100/100], Loss 0.3910
# Epoch 28/50, Train Loss 0.5849, Train Acc 0.8993, Test Loss 0.5743, Test Acc 0.9006
# Epoch [29/50], Batch [100/100], Loss 0.4340
# Epoch 29/50, Train Loss 0.5842, Train Acc 0.8997, Test Loss 0.5757, Test Acc 0.9001
# Epoch [30/50], Batch [100/100], Loss 0.3888
# Epoch 30/50, Train Loss 0.5848, Train Acc 0.8999, Test Loss 0.5744, Test Acc 0.9009
# Epoch [31/50], Batch [100/100], Loss 0.4242
# Epoch 31/50, Train Loss 0.5841, Train Acc 0.9003, Test Loss 0.5748, Test Acc 0.9033
# Epoch [32/50], Batch [100/100], Loss 0.4185
# Epoch 32/50, Train Loss 0.5846, Train Acc 0.8991, Test Loss 0.5763, Test Acc 0.9010
# Epoch [33/50], Batch [100/100], Loss 0.4372
# Epoch 33/50, Train Loss 0.5849, Train Acc 0.8993, Test Loss 0.5762, Test Acc 0.9006
# Epoch [34/50], Batch [100/100], Loss 0.4560
# Epoch 34/50, Train Loss 0.5846, Train Acc 0.9000, Test Loss 0.5748, Test Acc 0.9013
# Epoch [35/50], Batch [100/100], Loss 0.4522
# Epoch 35/50, Train Loss 0.5850, Train Acc 0.8990, Test Loss 0.5740, Test Acc 0.9013
# Epoch [36/50], Batch [100/100], Loss 0.4102
# Epoch 36/50, Train Loss 0.5852, Train Acc 0.8990, Test Loss 0.5753, Test Acc 0.9009
# Epoch [37/50], Batch [100/100], Loss 0.4423
# Epoch 37/50, Train Loss 0.5843, Train Acc 0.8994, Test Loss 0.5740, Test Acc 0.9006
# Epoch [38/50], Batch [100/100], Loss 0.3811
# Epoch 38/50, Train Loss 0.5842, Train Acc 0.8993, Test Loss 0.5738, Test Acc 0.9015
# Epoch [39/50], Batch [100/100], Loss 0.4043
# Epoch 39/50, Train Loss 0.5848, Train Acc 0.8982, Test Loss 0.5745, Test Acc 0.8994
# Epoch [40/50], Batch [100/100], Loss 0.3607
# Epoch 40/50, Train Loss 0.5844, Train Acc 0.8988, Test Loss 0.5745, Test Acc 0.8991
# Epoch [41/50], Batch [100/100], Loss 0.4977
# Epoch 41/50, Train Loss 0.5845, Train Acc 0.8984, Test Loss 0.5747, Test Acc 0.9010
# Epoch [42/50], Batch [100/100], Loss 0.4338
# Epoch 42/50, Train Loss 0.5850, Train Acc 0.8997, Test Loss 0.5759, Test Acc 0.8997
# Epoch [43/50], Batch [100/100], Loss 0.4288
# Epoch 43/50, Train Loss 0.5847, Train Acc 0.9006, Test Loss 0.5756, Test Acc 0.9023
# Epoch [44/50], Batch [100/100], Loss 0.4243
# Epoch 44/50, Train Loss 0.5840, Train Acc 0.8989, Test Loss 0.5745, Test Acc 0.9009
# Epoch [45/50], Batch [100/100], Loss 0.4528
# Epoch 45/50, Train Loss 0.5841, Train Acc 0.8988, Test Loss 0.5749, Test Acc 0.9010
# Epoch [46/50], Batch [100/100], Loss 0.3984
# Epoch 46/50, Train Loss 0.5853, Train Acc 0.9000, Test Loss 0.5761, Test Acc 0.9026
# Epoch [47/50], Batch [100/100], Loss 0.4100
# Epoch 47/50, Train Loss 0.5844, Train Acc 0.8993, Test Loss 0.5746, Test Acc 0.9023
# Epoch [48/50], Batch [100/100], Loss 0.4230
# Epoch 48/50, Train Loss 0.5840, Train Acc 0.8995, Test Loss 0.5747, Test Acc 0.9002
# Epoch [49/50], Batch [100/100], Loss 0.4131
# Epoch 49/50, Train Loss 0.5842, Train Acc 0.9000, Test Loss 0.5740, Test Acc 0.9007
# Epoch [50/50], Batch [100/100], Loss 0.4192
# Epoch 50/50, Train Loss 0.5852, Train Acc 0.8992, Test Loss 0.5753, Test Acc 0.8994
