# %% [markdown]
# ## This notebook includes:
#
# #### 1) Graph Convolutional Networks

# %% [markdown]
# # 1. Graph convolutional networks by [pygcn](https://github.com/tkipf/pygcn)

# %%
# !git clone https://github.com/tkipf/pygcn.git
# Out:
# /content
# Cloning into 'pygcn'...
# remote: Enumerating objects: 78, done.
# remote: Total 78 (delta 0), reused 0 (delta 0), pack-reused 78
# Unpacking objects: 100% (78/78), 226.59 KiB | 2.27 MiB/s, done.

# %%
import os
os.chdir('pygcn')
# Out:
# 0

# %% [markdown]
# ## 1.1 Install the package [pygcn@installation](https://github.com/tkipf/pygcn#installation)

# %%
# !python setup.py install
# Out:
# running install
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# creating pygcn.egg-info
# writing pygcn.egg-info/PKG-INFO
# writing dependency_links to pygcn.egg-info/dependency_links.txt
# writing requirements to pygcn.egg-info/requires.txt
# writing top-level names to pygcn.egg-info/top_level.txt
# writing manifest file 'pygcn.egg-info/SOURCES.txt'
# reading manifest file 'pygcn.egg-info/SOURCES.txt'
# adding license file 'LICENCE'
# writing manifest file 'pygcn.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# ...

# %% [markdown]
# ## 1.2 (To finish, 15 pts) Run the training code following [pygcn@usage](https://github.com/tkipf/pygcn#usage)

# %%
os.chdir("pygcn")
# !python train.py
# Out:
# Loading cora dataset...
# Epoch: 0001 loss_train: 1.9288 acc_train: 0.1571 loss_val: 1.9312 acc_val: 0.1567 time: 2.6852s
# Epoch: 0002 loss_train: 1.9206 acc_train: 0.1929 loss_val: 1.9196 acc_val: 0.1567 time: 0.0059s
# Epoch: 0003 loss_train: 1.9099 acc_train: 0.2000 loss_val: 1.9086 acc_val: 0.1567 time: 0.0051s
# Epoch: 0004 loss_train: 1.8911 acc_train: 0.2000 loss_val: 1.8977 acc_val: 0.1567 time: 0.0050s
# Epoch: 0005 loss_train: 1.8769 acc_train: 0.2071 loss_val: 1.8871 acc_val: 0.1567 time: 0.0050s
# Epoch: 0006 loss_train: 1.8744 acc_train: 0.2000 loss_val: 1.8767 acc_val: 0.1567 time: 0.0051s
# Epoch: 0007 loss_train: 1.8571 acc_train: 0.2000 loss_val: 1.8663 acc_val: 0.1567 time: 0.0051s
# Epoch: 0008 loss_train: 1.8535 acc_train: 0.2214 loss_val: 1.8562 acc_val: 0.1567 time: 0.0049s
# Epoch: 0009 loss_train: 1.8377 acc_train: 0.2143 loss_val: 1.8462 acc_val: 0.1567 time: 0.0050s
# ...

# %% [markdown]
# ## 1.3 Tuning the hyperparameters learniing rate from \{0.1, 0.01, 0.001\}, number of epochs from \{100,300\}, Number of hidden units from \{8, 32\}

# %%
# Your code goes here

print()
print(f"num_epochs = 100, lr = 0.1, hidden_size = 8")
# !python train.py --epochs 100 --lr 0.1 --hidden 8
print()
print(f"num_epochs = 100, lr = 0.1, hidden_size = 32")
# !python train.py --epochs 100 --lr 0.1 --hidden 32
print()
print(f"num_epochs = 100, lr = 0.01, hidden_size = 8")
# !python train.py --epochs 100 --lr 0.01 --hidden 8
print()
print(f"num_epochs = 100, lr = 0.01, hidden_size = 32")
# !python train.py --epochs 100 --lr 0.01 --hidden 32
print()
print(f"num_epochs = 100, lr = 0.001, hidden_size = 8")
# !python train.py --epochs 100 --lr 0.001 --hidden 8
print()
print(f"num_epochs = 100, lr = 0.001, hidden_size = 32")
# !python train.py --epochs 100 --lr 0.001 --hidden 32
print()
print(f"num_epochs = 300, lr = 0.1, hidden_size = 8")
# !python train.py --epochs 300 --lr 0.1 --hidden 8
print()
print(f"num_epochs = 300, lr = 0.1, hidden_size = 32")
# !python train.py --epochs 300 --lr 0.1 --hidden 32
print()
print(f"num_epochs = 300, lr = 0.01, hidden_size = 8")
# !python train.py --epochs 300 --lr 0.01 --hidden 8
print()
print(f"num_epochs = 300, lr = 0.01, hidden_size = 32")
# !python train.py --epochs 300 --lr 0.01 --hidden 32
print()
print(f"num_epochs = 300, lr = 0.001, hidden_size = 8")
# !python train.py --epochs 300 --lr 0.001 --hidden 8
print()
print(f"num_epochs = 300, lr = 0.001, hidden_size = 32")
# !python train.py --epochs 300 --lr 0.001 --hidden 32
# Out:
# num_epochs = 100, lr = 0.1, hidden_size = 8
# Loading cora dataset...
# Epoch: 0001 loss_train: 1.9978 acc_train: 0.1357 loss_val: 1.8964 acc_val: 0.1867 time: 0.6130s
# Epoch: 0002 loss_train: 1.8962 acc_train: 0.2643 loss_val: 1.8250 acc_val: 0.4633 time: 0.0051s
# Epoch: 0003 loss_train: 1.8177 acc_train: 0.3786 loss_val: 1.7741 acc_val: 0.3500 time: 0.0050s
# Epoch: 0004 loss_train: 1.7614 acc_train: 0.3357 loss_val: 1.7541 acc_val: 0.3500 time: 0.0050s
# Epoch: 0005 loss_train: 1.7631 acc_train: 0.3143 loss_val: 1.7240 acc_val: 0.3500 time: 0.0051s
# Epoch: 0006 loss_train: 1.7636 acc_train: 0.3071 loss_val: 1.6895 acc_val: 0.3667 time: 0.0050s
# Epoch: 0007 loss_train: 1.6584 acc_train: 0.3857 loss_val: 1.6529 acc_val: 0.4233 time: 0.0050s
# Epoch: 0008 loss_train: 1.6056 acc_train: 0.4143 loss_val: 1.6156 acc_val: 0.4800 time: 0.0051s
# Epoch: 0009 loss_train: 1.5565 acc_train: 0.4857 loss_val: 1.5725 acc_val: 0.5600 time: 0.0052s
# ...
